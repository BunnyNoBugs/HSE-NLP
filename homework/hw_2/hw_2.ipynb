# %% [markdown]
# ### Русский текст
#
# Вчера был очень необычный день. Сначала я услышал странный разговор. Один говорил другому: «Это невозможно! Эти типы стали есть на складе! Мало того, что после них образовалась течь, так мне потом пришлось и печь чистить!». Этот разговор я слышал, пока шел дорогой домой: видимо, они работают на заводе (у одного из них была в руках пила). Потом, когда я проходил мимо парка, я увидел, что от него остались только пни, а вокруг них жгут траву. Видимо, это они спугнули целый рой пчел, и он полетел за мной. Было страшно, как будто бы к виску приставили дуло пистолета. В общем, день был такой неординарный, что я даже решил стих о нем сочинить.
#
# В тексте присутствуют неоднозначные формы: "стали", "течь", "печь", "дорогой", "пила", "пни", "жгут", "рой", "дуло", "стих" и другие.
#
# ### Английский текст
#
# Yesterday was a really bad day. Firstly, I overheard a strange talk. One person was speaking to the other: “That is unbearable! There was a fellow who started eating at the warehouse! Not only I had to fix a leak after them, but I also had to clean the stove!”. I heard this conversation while I was on my way home. It seemed like both of them work at the factory (one of them had a saw in his hands). Later, when I was going past the park, I saw that only stumps were left of it and they were burning the grass around them. Apparently, they have scared off a swarm of bees and it started chasing me. I was so scared as if someone was threatening me with a gun. All in all, the day was so unusual that I have decided to write a few rhymes about it.
#
# Для английского текста даже не нужно было подбирать неоднозначные слова: они сами собой появились в переводе русского текста. По большей части это омонимия глагола и существительного-результата: "talk", "fix", "leak", "gun" и другие. Присутствуют также другие типы омонимий: прилагательное/существительное ("fellow"), несвязанные по смыслу существительное и форма глагола ("saw").

# %%
import glob

from nltk import word_tokenize

import pandas as pd

from pymystem3 import Mystem

# %%
text_paths = glob.glob('*.txt')

for i in text_paths:
    with open(i, encoding='utf-8') as f:
        text = f.read()
        text = [w for w in word_tokenize(text) if w.isalpha()]
        df = pd.DataFrame(text, columns={'token'})
        df.to_csv(i.replace('txt', 'csv'), sep='\t')

# %%
text = ' '.join(text)

# %%
m = Mystem()

# %%
lemmas = m.analyze(text)

# %%
lemmas
# Out:
# [{'analysis': [{'lex': 'вчера', 'wt': 0.9972698677, 'gr': 'ADV='}],
#   'text': 'Вчера'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,муж,несов'}],
#   'text': 'был'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'очень', 'wt': 1, 'gr': 'ADV='}], 'text': 'очень'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'необычный',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'необычный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'день',
#     'wt': 0.999920149,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'день'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сначала', 'wt': 1, 'gr': 'ADV='}], 'text': 'Сначала'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 0.9999716281, 'gr': 'SPRO,ед,1-л=им'}],
#   'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'услышать',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'услышал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'странный',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'странный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'разговор',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'разговор'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'один',
#     'wt': 0.68646993,
#     'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}],
#   'text': 'Один'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'говорить',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'говорил'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'другой',
#     'wt': 0.9998677227,
#     'gr': 'APRO=(дат,ед,муж|дат,ед,сред)'}],
#   'text': 'другому'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'это',
#     'wt': 0.7809833731,
#     'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'Это'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'невозможно', 'wt': 0.04165616786, 'gr': 'ADV='}],
#   'text': 'невозможно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'этот', 'wt': 1, 'gr': 'APRO=(им,мн|вин,мн,неод)'}],
#   'text': 'Эти'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тип',
#     'wt': 0.8700298642,
#     'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'типы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'становиться',
#     'wt': 0.9821285244,
#     'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'стали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'есть', 'wt': 0.0492236161, 'gr': 'V,несов,пе=инф'}],
#   'text': 'есть'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'на', 'wt': 0.9989522965, 'gr': 'PR='}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'склад', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'складе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мало', 'wt': 0.6694873782, 'gr': 'ADV='}],
#   'text': 'Мало'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'то',
#     'wt': 0.7857450701,
#     'gr': 'SPRO,ед,сред,неод=род'}],
#   'text': 'того'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'что', 'wt': 0.688532576, 'gr': 'CONJ='}],
#   'text': 'что'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'после', 'wt': 0.9774551099, 'gr': 'PR='}],
#   'text': 'после'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'они', 'wt': 1, 'gr': 'SPRO,мн=(пр|вин|род)'}],
#   'text': 'них'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'образовываться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,жен,сов'}],
#   'text': 'образовалась'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'течь', 'wt': 0.7621620799, 'gr': 'V,несов,нп=инф'}],
#   'text': 'течь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'так', 'wt': 0.9840554802, 'gr': 'ADVPRO='}],
#   'text': 'так'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 1, 'gr': 'SPRO,ед,1-л=(пр|дат)'}],
#   'text': 'мне'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'потом', 'wt': 0.9973603863, 'gr': 'ADVPRO='}],
#   'text': 'потом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приходиться',
#     'wt': 0.9982644245,
#     'gr': 'V,нп=прош,ед,изъяв,сред,сов'}],
#   'text': 'пришлось'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'печь',
#     'wt': 0.9114089249,
#     'gr': 'S,жен,неод=(вин,ед|им,ед)'}],
#   'text': 'печь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'чистить', 'wt': 1, 'gr': 'V,несов,пе=инф'}],
#   'text': 'чистить'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'этот',
#     'wt': 1,
#     'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}],
#   'text': 'Этот'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'разговор',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'разговор'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 0.9999716281, 'gr': 'SPRO,ед,1-л=им'}],
#   'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'слышать',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'слышал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пока', 'wt': 0.6671385998, 'gr': 'CONJ='}],
#   'text': 'пока'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'идти', 'wt': 1, 'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'шел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дорогой',
#     'wt': 0.7123265812,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'дорогой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'домой', 'wt': 0.9999989314, 'gr': 'ADV='}],
#   'text': 'домой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'видимо', 'wt': 0.9969616688, 'gr': 'ADV,вводн='}],
#   'text': 'видимо'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'они', 'wt': 1, 'gr': 'SPRO,мн=им'}], 'text': 'они'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'работать',
#     'wt': 1,
#     'gr': 'V,несов,нп=непрош,мн,изъяв,3-л'}],
#   'text': 'работают'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'на', 'wt': 0.9989522965, 'gr': 'PR='}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'завод', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'заводе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'у', 'wt': 0.9993940324, 'gr': 'PR='}], 'text': 'у'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'один',
#     'wt': 0.698218405,
#     'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}],
#   'text': 'одного'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'из', 'wt': 0.9999999775, 'gr': 'PR='}], 'text': 'из'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'они', 'wt': 1, 'gr': 'SPRO,мн=(пр|вин|род)'}],
#   'text': 'них'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,жен,несов'}],
#   'text': 'была'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'рука', 'wt': 1, 'gr': 'S,жен,неод=пр,мн'}],
#   'text': 'руках'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пить',
#     'wt': 0.8391285768,
#     'gr': 'V,несов,пе=прош,ед,изъяв,жен'}],
#   'text': 'пила'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'потом', 'wt': 0.9973603863, 'gr': 'ADVPRO='}],
#   'text': 'Потом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'когда', 'wt': 0.8251525963, 'gr': 'CONJ='}],
#   'text': 'когда'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 0.9999716281, 'gr': 'SPRO,ед,1-л=им'}],
#   'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'проходить',
#     'wt': 0.7111145396,
#     'gr': 'V=(прош,ед,изъяв,муж,сов,пе|прош,ед,изъяв,муж,несов,пе)'}],
#   'text': 'проходил'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мимо', 'wt': 0.7646968426, 'gr': 'PR='}],
#   'text': 'мимо'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'парк', 'wt': 0.9620898542, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'парка'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 0.9999716281, 'gr': 'SPRO,ед,1-л=им'}],
#   'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'увидеть',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'увидел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'что', 'wt': 0.688532576, 'gr': 'CONJ='}],
#   'text': 'что'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'от', 'wt': 1, 'gr': 'PR='}], 'text': 'от'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'он',
#     'wt': 0.951862938,
#     'gr': 'SPRO,ед,3-л,муж=(вин|род)'}],
#   'text': 'него'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'оставаться', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'остались'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'только', 'wt': 0.9073895266, 'gr': 'PART='}],
#   'text': 'только'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пень',
#     'wt': 0.9543276194,
#     'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'пни'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'а', 'wt': 0.9822148501, 'gr': 'CONJ='}], 'text': 'а'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вокруг', 'wt': 0.7756739946, 'gr': 'PR='}],
#   'text': 'вокруг'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'они', 'wt': 1, 'gr': 'SPRO,мн=(пр|вин|род)'}],
#   'text': 'них'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'жечь',
#     'wt': 0.7205134187,
#     'gr': 'V,несов,пе=непрош,мн,изъяв,3-л'}],
#   'text': 'жгут'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'трава', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'траву'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'видимо', 'wt': 0.9969616688, 'gr': 'ADV,вводн='}],
#   'text': 'Видимо'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'это',
#     'wt': 0.7809833731,
#     'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'это'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'они', 'wt': 1, 'gr': 'SPRO,мн=им'}], 'text': 'они'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'спугивать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,сов'}],
#   'text': 'спугнули'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'целый',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'целый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'рой',
#     'wt': 0.4925193417,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'рой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пчела', 'wt': 1, 'gr': 'S,жен,од=(вин,мн|род,мн)'}],
#   'text': 'пчел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'он', 'wt': 1, 'gr': 'SPRO,ед,3-л,муж=им'}],
#   'text': 'он'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'полететь',
#     'wt': 1,
#     'gr': 'V,сов,нп=прош,ед,изъяв,муж'}],
#   'text': 'полетел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'за', 'wt': 1, 'gr': 'PR='}], 'text': 'за'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 1, 'gr': 'SPRO,ед,1-л=твор'}],
#   'text': 'мной'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть',
#     'wt': 0.975680698,
#     'gr': 'V,нп=прош,ед,изъяв,сред,несов'}],
#   'text': 'Было'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'страшно', 'wt': 0.783890729, 'gr': 'ADV='}],
#   'text': 'страшно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'как', 'wt': 0.3756069802, 'gr': 'ADVPRO='}],
#   'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'будто', 'wt': 0.6150145335, 'gr': 'PART='}],
#   'text': 'будто'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'бы', 'wt': 1, 'gr': 'PART='}], 'text': 'бы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'к', 'wt': 0.9999551798, 'gr': 'PR='}], 'text': 'к'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'висок',
#     'wt': 0.9478622275,
#     'gr': 'S,муж,неод=дат,ед'}],
#   'text': 'виску'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приставлять',
#     'wt': 1,
#     'gr': 'V,пе=прош,мн,изъяв,сов'}],
#   'text': 'приставили'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дуло',
#     'wt': 0.6081028818,
#     'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'дуло'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пистолет', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'пистолета'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'общий',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}],
#   'text': 'общем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'день',
#     'wt': 0.999920149,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'день'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,муж,несов'}],
#   'text': 'был'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'такой',
#     'wt': 1,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|вин,ед,муж,неод|им,ед,муж)'}],
#   'text': 'такой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'неординарный',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'неординарный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'что', 'wt': 0.688532576, 'gr': 'CONJ='}],
#   'text': 'что'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 0.9999716281, 'gr': 'SPRO,ед,1-л=им'}],
#   'text': 'я'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'даже', 'wt': 0.8211751077, 'gr': 'PART='}],
#   'text': 'даже'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'решать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,сов'}],
#   'text': 'решил'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'стих',
#     'wt': 0.7112022431,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'стих'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'о', 'wt': 0.9737875835, 'gr': 'PR='}], 'text': 'о'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'он', 'wt': 0.8501841275, 'gr': 'SPRO,ед,3-л,муж=пр'}],
#   'text': 'нем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сочинять', 'wt': 1, 'gr': 'V,пе=инф,сов'}],
#   'text': 'сочинить'},
#  {'text': '\n'}]

# %%
a = [1, 2]
pd.DataFrame(a, columns={'sdf', 'asdf'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1677                 blocks = [
# -> 1678                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1679                 ]
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3266
# -> 3267     return klass(values, ndim=ndim, placement=placement)
#    3268
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     127                 "Wrong number of items passed {val}, placement implies "
# --> 128                 "{mgr}".format(val=len(self.values), mgr=len(self.mgr_locs))
#     129             )
#
# ValueError: Wrong number of items passed 1, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-0f4468f1b73e> in <module>
#       1 a = [1, 2]
# ----> 2 pd.DataFrame(a, columns={'sdf', 'asdf'})
#
# c:\program files\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     463                 else:
# --> 464                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465             else:
#     466                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     211         block_values = [values]
#     212
# --> 213     return create_block_manager_from_blocks(block_values, [columns, index])
#     214
#     215
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1686         blocks = [getattr(b, "values", b) for b in blocks]
#    1687         tot_items = sum(b.shape[0] for b in blocks)
# -> 1688         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1689
#    1690
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1717         raise ValueError("Empty data passed with indices specified.")
#    1718     raise ValueError(
# -> 1719         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1720     )
#    1721
#
# ValueError: Shape of passed values is (2, 1), indices imply (2, 2)

# %%
text_paths
# Out:
# ['english.txt', 'russian.txt']
